# %% [markdown]
# ## Creating Dataset

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(123)

# %%
n_samples=1000
class_0_ratio=0.9
n_class_0=int(n_samples*class_0_ratio)
n_class_1=int(n_samples-n_class_0)

# %%
print(n_class_1,n_class_0)
# Out:
# 100 900

# %%
n_class_0=pd.DataFrame({'Feature1':np.random.normal(loc=0,scale=1,size=n_class_0)})
