# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df['Height'],df['Weight'])

# %%
import seaborn as sns
sns.pairplot(df)

# %%
## Independent and dependent features
X=df[['Weight']] ##independent features should be dataframe or 2 demensional
np.array(X).shape
Y=df['Height']

# %%
## Train test split 
# !pip install scikit-learn
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=42)
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from scikit-learn) (2.3.5)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.16.3-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-macosx_12_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 5.7 MB/s  0:00:01 eta 0:00:01
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached scipy-1.16.3-cp314-cp314-macosx_14_0_arm64.whl (20.9 MB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.16.3 threadpoolctl-3.6.0

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression(n_jobs=-1)
regression.fit(X_train,Y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
regression.coef_
# Out:
# array([17.2982057])

# %%
regression.intercept_
# Out:
# np.float64(156.47058823529412)

# %%
plt.scatter(X_train,Y_train)
plt.plot(X_train,regression.predict(X_train))

# %%
y_predict=regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(Y_test,y_predict)
print(mse)
# Out:
# 114.84069295228699

# %%
mae=mean_absolute_error(Y_test,y_predict)
print(mae)
# Out:
# 9.66512588679501

# %%
from sklearn.metrics import r2_score
score=r2_score(Y_test,y_predict)
print(score)
# Out:
# 0.7360826717981276

# %%
##OLS LinearRegression
# !pip install Statsmodels
import statsmodels.api as sm
# Out:
# Requirement already satisfied: Statsmodels in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from Statsmodels) (2.3.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from Statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from Statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from Statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from Statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from pandas!=2.1.0,>=1.4->Statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from pandas!=2.1.0,>=1.4->Statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from pandas!=2.1.0,>=1.4->Statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->Statsmodels) (1.17.0)

# %%
model=sm.OLS(Y_train,X_train).fit()

# %%
prediction=model.predict(X_test)

# %%
print(prediction)
# Out:
# [  5.79440897   5.79440897 -28.78711691  23.60913442  -7.82861638
#   34.08838469]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Height   R-squared (uncentered):                   0.012
# Model:                            OLS   Adj. R-squared (uncentered):             -0.050
# Method:                 Least Squares   F-statistic:                             0.1953
# Date:                Thu, 08 Jan 2026   Prob (F-statistic):                       0.664
# Time:                        15:14:38   Log-Likelihood:                         -110.03
# No. Observations:                  17   AIC:                                      222.1
# Df Residuals:                      16   BIC:                                      222.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            17.2982     39.138      0.442      0.664     -65.671     100.267
# ==============================================================================
# Omnibus:                        0.135   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.935   Jarque-Bera (JB):                0.203
# Skew:                          -0.166   Prob(JB):                        0.904
# Kurtosis:                       2.581   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
regression.predict(scaler.transform([[72]]))
# Out:
# /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([155.97744705])
