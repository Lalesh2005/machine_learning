# %%
# !pip install tensorflow
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.0.0-rc0 (from versions: 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow==2.0.0-rc0

# %%
# !pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [77 lines of output]
#       Traceback (most recent call last):
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/_vendor/packaging/requirements.py", line 36, in __init__
#           parsed = _parse_requirement(requirement_string)
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/_vendor/packaging/_parser.py", line 71, in parse_requirement
#           return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/_vendor/packaging/_parser.py", line 89, in _parse_requirement
#           url, specifier, marker = _parse_requirement_details(tokenizer)
#                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/_vendor/packaging/_parser.py", line 135, in _parse_requirement_details
#           marker = _parse_requirement_marker(
#               tokenizer,
#           ...<5 lines>...
#               ),
#           )
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/_vendor/packaging/_parser.py", line 156, in _parse_requirement_marker
#           tokenizer.raise_syntax_error(
#           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#               f"Expected {expected} or end",
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               span_start=span_start,
#               ^^^^^^^^^^^^^^^^^^^^^^
#               span_end=None,
#               ^^^^^^^^^^^^^^
#           )
#           ^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/_vendor/packaging/_tokenizer.py", line 166, in raise_syntax_error
#           raise ParserSyntaxError(
#           ...<3 lines>...
#           )
#       packaging._tokenizer.ParserSyntaxError: Expected semicolon (after name with no version specifier) or end
#           python_version>"3.7"
#                         ^
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "/Users/laleshkumar/Python_course/.venv/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "/Users/laleshkumar/Python_course/.venv/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/laleshkumar/Python_course/.venv/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 40, in <module>
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/__init__.py", line 114, in setup
#           _install_setup_requires(attrs)
#           ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/__init__.py", line 85, in _install_setup_requires
#           dist.parse_config_files(ignore_option_errors=True)
#           ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/dist.py", line 764, in parse_config_files
#           self._finalize_requires()
#           ~~~~~~~~~~~~~~~~~~~~~~~^^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/dist.py", line 382, in _finalize_requires
#           self._normalize_requires()
#           ~~~~~~~~~~~~~~~~~~~~~~~~^^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/dist.py", line 400, in _normalize_requires
#           self.install_requires = list_(map(str, _reqs.parse(install_requires)))
#                                   ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/yb/1vxfk8_x2fbdnqhyn4mynsnr0000gn/T/pip-build-env-uwtsfv0g/overlay/lib/python3.13/site-packages/setuptools/_vendor/packaging/requirements.py", line 38, in __init__
#           raise InvalidRequirement(str(e)) from e
#       packaging.requirements.InvalidRequirement: Expected semicolon (after name with no version specifier) or end
#           python_version>"3.7"
#                         ^
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'tensorflow-gpu' when getting requirements to build wheel

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense

# %%
print(tf.__version__)
# Out:
# 2.21.0

# %%
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
X= dataset.drop(labels=['CustomerId','Surname','RowNumber','Exited'],axis=1)
y=dataset['Exited']

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          619    France  Female  ...          1               1        101348.88
# 1          608     Spain  Female  ...          0               1        112542.58
# 2          502    France  Female  ...          1               0        113931.57
# 3          699    France  Female  ...          0               0         93826.63
# 4          850     Spain  Female  ...          1               1         79084.10
#
# [5 rows x 10 columns]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label1=LabelEncoder()
X['Geography']=label1.fit_transform(X['Geography'])

# %%
X.head()
# Out:
#    CreditScore  Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          619          0  Female  ...          1               1        101348.88
# 1          608          2  Female  ...          0               1        112542.58
# 2          502          0  Female  ...          1               0        113931.57
# 3          699          0  Female  ...          0               0         93826.63
# 4          850          2  Female  ...          1               1         79084.10
#
# [5 rows x 10 columns]

# %%
label=LabelEncoder()
X['Gender']=label.fit_transform(X['Gender'])
X.head()
# Out:
#    CreditScore  Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          619          0       0  ...          1               1        101348.88
# 1          608          2       0  ...          0               1        112542.58
# 2          502          0       0  ...          1               0        113931.57
# 3          699          0       0  ...          0               0         93826.63
# 4          850          2       0  ...          1               1         79084.10
#
# [5 rows x 10 columns]

# %%
X = pd.get_dummies(X, drop_first=True, columns=['Geography'])
X.head()
# Out:
#    CreditScore  Gender  Age  ...  EstimatedSalary  Geography_1  Geography_2
# 0          619       0   42  ...        101348.88        False        False
# 1          608       0   41  ...        112542.58        False         True
# 2          502       0   42  ...        113931.57        False        False
# 3          699       0   39  ...         93826.63        False        False
# 4          850       0   43  ...         79084.10        False         True
#
# [5 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0,stratify=y)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-1.24021723, -1.09665089,  0.77986083, ...,  1.64099027,
#         -0.57812007, -0.57504086],
#        [ 0.75974873,  0.91186722, -0.27382717, ..., -1.55587522,
#          1.72974448, -0.57504086],
#        [-1.72725557, -1.09665089, -0.9443559 , ...,  1.1038111 ,
#         -0.57812007, -0.57504086],
#        ...,
#        [-0.51484098,  0.91186722,  0.87565065, ..., -1.01507508,
#          1.72974448, -0.57504086],
#        [ 0.73902369, -1.09665089, -0.36961699, ..., -1.47887193,
#         -0.57812007, -0.57504086],
#        [ 0.95663657,  0.91186722, -1.32751517, ...,  0.50945854,
#         -0.57812007,  1.73900686]], shape=(8000, 11))

# %% [markdown]
# ## Build ANN
# • First Layer (Input + Hidden)
# – neurons = number of features (11)
# – activation = ReLU
# • Second Layer
# – 128 neurons → more learning power
# • Output Layer
# – 1 neuron (binary classification)
# – sigmoid → gives probability

# %%
model=Sequential()
model.add(Dense(X.shape[1],activation='relu',input_dim=X.shape[1]))
model.add(Dense(128,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /Users/laleshkumar/Python_course/.venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
X.shape[1]
# Out:
# 11

# %% [markdown]
# • optimizer = Adam → updates weights
# • loss = binary_crossentropy → for 0/1 output

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train.to_numpy(),batch_size=10,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 421us/step - accuracy: 0.8095 - loss: 0.4462
# Epoch 2/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - accuracy: 0.8372 - loss: 0.3974
# Epoch 3/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - accuracy: 0.8540 - loss: 0.3623
# Epoch 4/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - accuracy: 0.8606 - loss: 0.3494
# Epoch 5/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.8597 - loss: 0.3440
# Epoch 6/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - accuracy: 0.8616 - loss: 0.3398
# Epoch 7/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - accuracy: 0.8631 - loss: 0.3377
# Epoch 8/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - accuracy: 0.8639 - loss: 0.3345
# Epoch 9/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - accuracy: 0.8631 - loss: 0.3330
# Epoch 10/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - accuracy: 0.8631 - loss: 0.3319

# %%
y_pred = model.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step

# %%
y_pred
# Out:
# array([[0.18276347],
#        [0.14273897],
#        [0.02968303],
#        ...,
#        [0.03613239],
#        [0.9999863 ],
#        [0.05879872]], shape=(2000, 1), dtype=float32)

# %%
y_test
# Out:
# 1344    1
# 8167    0
# 4747    0
# 5004    1
# 3124    1
#        ..
# 9107    0
# 8249    0
# 8337    0
# 6279    1
# 412     0
# Name: Exited, Length: 2000, dtype: int64

# %%
model.evaluate(X_test,y_test.to_numpy())
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - accuracy: 0.8525 - loss: 0.3472
# [0.34720370173454285, 0.8525000214576721]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
y_pred_binary = (y_pred > 0.5).astype(int).flatten()
confusion_matrix(y_test, y_pred_binary)
# Out:
# array([[1511,   82],
#        [ 213,  194]])

# %%
accuracy_score(y_test, y_pred_binary)
# Out:
# 0.8525
