# %% [markdown]
# ## Central Tendency -- Mean,Median,Mode

# %%
## Mean
import numpy as np
list = [1,2,3,4,5,5]
np.mean(list)
# Out:
# np.float64(3.3333333333333335)

# %%
## Median
np.median(list)
# Out:
# np.float64(3.5)

# %%
## Mode
values, counts = np.unique(list, return_counts=True)
mode = values[np.argmax(counts)]
print(mode)
# Out:
# 5

# %% [markdown]
# ## Dispersion

# %%
# Range
range_val = np.max(list) - np.min(list)

# Variance
variance = np.var(list)

# Standard Deviation
std_dev = np.std(list)

print(range_val)
print(variance)
print(std_dev)
# Out:
# 4
# 2.2222222222222223
# 1.4907119849998598

# %%
import matplotlib.pyplot as plt

# Data
students = ["A", "B", "C", "D"]
marks = [85, 90, 78, 92]

# Line Plot
plt.plot(students, marks)
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()
