# %% [markdown]
# ## Tokenization

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Downloading click-8.3.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in /Users/laleshkumar/Python_course/.venv/lib/python3.14/site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.4.4-cp314-cp314-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 1.7 MB/s  0:00:00 eta 0:00:01
# Downloading regex-2026.4.4-cp314-cp314-macosx_11_0_arm64.whl (289 kB)
# Downloading click-8.3.2-py3-none-any.whl (108 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, click, nltk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [nltk]3/4 [nltk]
# Successfully installed click-8.3.2 nltk-3.9.4 regex-2026.4.4 tqdm-4.67.3
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
corpus='''Hello welcome to lalesh's NLP tutorial.please do watch the entire course! to become expert in NLP.'''

# %%
print(corpus)
# Out:
# Hello welcome to lalesh's NLP tutorial.please do watch the entire course! to become expert in NLP.

# %%
## Tkenization 
from nltk.tokenize import sent_tokenize

# %%
import nltk as nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/laleshkumar/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
document = sent_tokenize(corpus)

# %%
type(document)
# Out:
# list

# %%
for sentence in document:
    print(sentence)
# Out:
# Hello welcome to lalesh's NLP tutorial.please do watch the entire course!
# to become expert in NLP.

# %%
from nltk.tokenize import word_tokenize

# %%
for sentence in document:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', 'to', 'lalesh', "'s", 'NLP', 'tutorial.please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'lalesh',
#  "'",
#  's',
#  'NLP',
#  'tutorial',
#  '.',
#  'please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer= TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'lalesh',
#  "'s",
#  'NLP',
#  'tutorial.please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
