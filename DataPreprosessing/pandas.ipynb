# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 325.2 kB/s  0:00:32 eta 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# ...

# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
series=pd.Series(data)
print("series\n",series)
# Out:
# series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
### create series from dictionary
data={'a':1,'b':2,'c':3}
series_dict=pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## Dataframe
## create a dataframe from dict of list 
data={
    'Name':['lalesh','john','jack'],
    'Age':[20,10,15],
    'city':['A','B','C']
}
pd.DataFrame(data)
# Out:
#      Name  Age city
# 0  lalesh   20    A
# 1    john   10    B
# 2    jack   15    C

# %%
## create a Data frame from the list of  dictionaries 
data=[
    {'Name':'Lalesh','Age':20,'City':'stm'},
    {'Name':'rajesh','Age':25,'City':'patna'},
    {'Name':'Naman','Age':19,'City':'kolkata'},
   
    
]
df=pd.DataFrame(data)
print(df)
# Out:
#      Name  Age     City
# 0  Lalesh   20      stm
# 1  rajesh   25    patna
# 2   Naman   19  kolkata

# %%
df=pd.read_csv('sales_data.csv')
print(df.head())  # first 5 rows
df.describe()
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
#              price    quantity      revenue
# count   367.000000  368.000000   368.000000
# mean    211.226158   14.565217  2060.679348
# std     227.335170    8.595740  1910.930790
# min      20.000000    3.000000   300.000000
# 25%      50.000000    8.000000   800.000000
# 50%     100.000000   12.000000  1200.000000
# 75%     300.000000   20.000000  2400.000000
# max    1200.000000   50.000000  7200.000000

# %%
df.loc[0] ## shows row
# Out:
# date         2022-01-01
# product      Smartphone
# category    Electronics
# price             600.0
# quantity           10.0
# revenue          6000.0
# Name: 0, dtype: object

# %%
df.iloc[1] ## index
# Out:
# date         2022-01-01
# product          Laptop
# category    Electronics
# price            1200.0
# quantity            5.0
# revenue          6000.0
# Name: 1, dtype: object

# %%
## Accessing specified element
data={
    'Name':['lalesh','john','jack'],
    'Age':[20,30,15],
    'city':['A','B','C']
}
df=pd.DataFrame(data)
df['Name']
# Out:
# 0    lalesh
# 1      john
# 2      jack
# Name: Name, dtype: object

# %%
df.at[1,'Age']
# Out:
# np.int64(30)

# %%
## Accesssing a specified element using iat
df.iat[2,2]
# Out:
# 'C'

# %%
### DATA manupulation with DataFarame
df['Salary']=[50000,60000,70000]
print(df)
# Out:
#      Name  Age city  Salary
# 0  lalesh   20    A   50000
# 1    john   30    B   60000
# 2    jack   15    C   70000

# %%
## Remove a coloumn
df.drop('Salary',axis=1,inplace=True) ## axis=0  by default it checks in row if 
## we write axis=1 it checks in coloumn
## drop is not permanent so we have to do inplace=True

# %%
df
# Out:
#      Name  Age city
# 0  lalesh   23    A
# 1    john   33    B
# 2    jack   18    C

# %%
### Add age to the coloumn
df['Age']=df['Age']+1
df
# Out:
#      Name  Age city
# 0  lalesh   24    A
# 1    john   34    B
# 2    jack   19    C
