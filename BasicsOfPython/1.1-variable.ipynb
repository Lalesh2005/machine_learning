# %%
print("Hello")
# Out:
# Hello

# %%
age=13
print(type(age))

## type conversion 

str_age=str(age)
print(type(str_age))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=input("Enter the age")
print(age,type(age))
# Out:
# Lalesh <class 'str'>
