# %% [markdown]
# * Q1 — Student Management System

# %%
class Student:
    def __init__(self,name,roll_number,branch):
        self.name=name
        self.roll_number=roll_number
        self.branch=branch
    
    def display_info(self):
        print(f"Name:- {self.name}\nroll_number:- {self.roll_number}\nbranch:- {self.branch}")
        print("_______________________________________________________________________")

student1 = Student("Lalesh", 101, "CSE")
student2 = Student("Raj", 102, "ECE")
student1.display_info()
student2.display_info()
# Out:
# Name:- Lalesh
# roll_number:- 101
# branch:- CSE
# _______________________________________________________________________
# Name:- Raj
# roll_number:- 102
# branch:- ECE
# _______________________________________________________________________

# %% [markdown]
# * Q2 — Bank Account (Constructor Validation)

# %%
class BankAccount:

    def __init__(self, name, account_number, balance):

        if balance < 0:
            raise ValueError("Balance cannot be negative")

        self.account_holder_name = name
        self.account_number = account_number
        self.balance = balance

    def display_account(self):

        print(f"Name: {self.account_holder_name}")
        print(f"Account Number: {self.account_number}")
        print(f"Balance: {self.balance}")
acc1 = BankAccount("Lalesh",101,5000)
#acc2 = BankAccount("Raj",102,-1000)
acc1.display_account()
#acc2.display_account()
# Out:
# Name: Lalesh
# Account Number: 101
# Balance: 5000

# %% [markdown]
# * Q3 — Vehicle Management System

# %%
class Vehicle:
    def __init__(self,brand,speed):
        self.brand=brand
        self.speed=speed
    def display_vehicle(self):
        print(f"Brand: {self.brand}")
        print(f"speed: {self.speed}")
class Car(Vehicle):
    def __init__(self,brand,speed,fuel_type):
        super().__init__(brand,speed)
        self.fuel_type=fuel_type  
    def display_car(self):
        print(f"Brand: {self.brand}")
        print(f"speed: {self.speed}")
        print(f"fuel_type: {self.fuel_type}")
car1 = Car("BMW", 200, "Petrol")
car1.display_car()
# Out:
# Brand: BMW
# speed: 200
# fuel_type: Petrol

# %% [markdown]
# * Q4 — Multilevel Inheritance

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display_person(self):
        print(f"Name:- {self.name}")
        print(f"Age:- {self.age}")
        
class Employee(Person):
    def __init__(self,name,age,employee_id,salary):
        super().__init__(name,age)
        self.employee_id=employee_id
        self.salary=salary
    def display_employee(self):
        print(f"Name:- {self.name}")
        print(f"Age:- {self.age}")  
        print(f"employee_id:- {self.employee_id}")     
        print(f"salary:- {self.salary}")
        
class Manager(Employee):
    def __init__(self,name,age,employee_id,salary,department):
        super().__init__(name,age,employee_id,salary)
        self.department=department
    def display_manager(self):
        print(f"Name:- {self.name}")
        print(f"Age:- {self.age}")  
        print(f"employee_id:- {self.employee_id}")     
        print(f"salary:- {self.salary}")
        print(f"Department:- {self.department}")
manager1 = Manager("Lalesh",20,"EMP101",80000,"AI Team")
manager1.display_manager()
# Out:
# Name:- Lalesh
# Age:- 20
# employee_id:- EMP101
# salary:- 80000
# Department:- AI Team

# %% [markdown]
# * Q5 — Hierarchical Inheritance

# %%
class Animal:
    def __init__(self,name):
        self.name=name
    def sound(self):
        print("sound of the animal")
class Dog(Animal):
    def __init__(self,name):
        super().__init__(name)
    def sound(self):
        print("Bark Bark!")
class Cat(Animal):
    def __init__(self,name):
        super().__init__(name)
    def sound(self):
        print("Meow Meow!")
dog = Dog("Tommy")
cat = Cat("Kitty")
dog.sound()
cat.sound()
# Out:
# Bark Bark!
# Meow Meow!

# %% [markdown]
# * Q6 — Multiple Inheritance

# %%
class Camera:
    def take_photo(self):
        print("Photo Captured")
class Phone:
    def make_call(self):
        print("Calling...")
class SmartPhone(Camera,Phone):
    pass
iphone = SmartPhone()
iphone.take_photo()
iphone.make_call()
# Out:
# Photo Captured
# Calling...

# %% [markdown]
# * Q7 — Hybrid Inheritance

# %%
class Employee:
    def __init__(self,name,employee_id):
        self.name=name
        self.employee_id = employee_id
    def show_details(self):
        print(f"Name:- {self.name}")
        print(f"Employee_ID:- {self.employee_id}")
class Developer(Employee):   
    def write_code(self):
        print("Writing Code...")
class Designer(Employee):
    def design_ui(self):
        print("Designing UI...")

class TeamLead(Developer,Designer):
    def __init__(self, name, employee_id):
        super().__init__(name, employee_id)
lead = TeamLead("Lalesh","EMP101")
lead.write_code()
lead.design_ui()
# Out:
# Writing Code...
# Designing UI...

# %% [markdown]
# * 🚀 Q8 — Polymorphism (Shape Area)

# %%
class Shape:
    def area(self):
        print("Gives the area of the shapes")
class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        print(f"Area of circle is of radius {self.radius} = {3.14*self.radius*self.radius}")

class Rectangle(Shape):
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        print(f"Area of rectangle is {self.length*self.width}")

circle = Circle(5)
rectangle = Rectangle(4,6)

circle.area()
rectangle.area()
# Out:
# Area of circle is of radius 5 = 78.5
# Area of rectangle is 24

# %% [markdown]
# * 🚀 Q9 — Notification System (Polymorphism)

# %%
class Notification:
    def send(self):
        print("provide notification feature")
class EmailNotification(Notification):
    def send(self):
        print("Email Sent")
class SMSNotification(Notification):
    def send(self):
        print("SMS Sent")
class PushNotification(Notification):
    def send(self):
        print("Push Notification Sent")
notifications = [
    EmailNotification(),
    SMSNotification(),
    PushNotification()
]

for n in notifications:
    n.send()
# Out:
# Email Sent
# SMS Sent
# Push Notification Sent

# %% [markdown]
# * 🚀 Q10 — Payment System (Most Interview-Friendly Polymorphism)

# %%
class Payment:
    def pay(self, amount):
        print("Provides payment gateway")
class CreditCardPayment(Payment):
    def pay(self, amount):
        print(f"Paid ₹{amount} using Credit Card")
class UPIPayment(Payment):
    def pay(self, amount):
        print(f"Paid ₹{amount} using UPI")
class WalletPayment(Payment):
    def pay(self, amount):
        print(f"Paid ₹{amount} using Wallet")
payments = [
    CreditCardPayment(),
    UPIPayment(),
    WalletPayment()
]
for p in payments:
    p.pay(500)
# Out:
# Paid ₹500 using Credit Card
# Paid ₹500 using UPI
# Paid ₹500 using Wallet

# %% [markdown]
# * Q11 — Vehicle Abstraction

# %%
from abc import ABC, abstractmethod
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass
    @abstractmethod
    def stop_engine(self):
        pass
class Car(Vehicle):
    def start_engine(self):
        print("Car Engine Started")
    def stop_engine(self):
        print("Car Engine Stopped")
class Bike(Vehicle):
    def start_engine(self):
        print("bike Engine Started")

    def stop_engine(self):
        print("bike Engine Stopped")        
car = Car()
bike = Bike()

car.start_engine()
bike.start_engine()

car.stop_engine()
bike.stop_engine()
# Out:
# Car Engine Started
# bike Engine Started
# Car Engine Stopped
# bike Engine Stopped

# %% [markdown]
# * Q12 — Bank Account Encapsulation

# %%
class BankAccount:
    def __init__(self,account_holder,balance):
        self.account_holder = account_holder
        self.__balance = balance
    def deposit(self,balance):
        self.__balance+=balance
        print("money deposited.")
    
    def withdraw(self,balance):
        if(balance<=self.__balance):
            self.__balance-=balance
            print("Money withdrawn.")
        else:
            print("Isufficient balance.")
    def show_balance(self):
        print(f"Balance:{self.__balance}")
acc = BankAccount("Lalesh", 5000)

acc.deposit(1000)
acc.withdraw(2000)

acc.show_balance()
# Out:
# money deposited.
# Money withdrawn.
# Balance:4000

# %% [markdown]
# * 🚀 Q12 — Composition (Very Important)

# %%
class Engine:
    def start(self):
        print("Engine Started.")

class Car:
    def __init__(self):
        self.engine = Engine()
    def start_car(self):
        self.engine.start()
car = Car()
car.start_car()
# Out:
# Engine Started.

# %% [markdown]
# * 🚀 Q13 — @staticmethod

# %%
class MathUtils:
    @staticmethod
    def add(a,b):
        return a+b
print(MathUtils.add(10,20))
# Out:
# 30

# %% [markdown]
# * 🚀 Final OOP Topic — Q14 @classmethod

# %%
class Student:

    count = 0

    def __init__(self):
        Student.count += 1

    @classmethod
    def get_count(cls):
        return cls.count


s1 = Student()
s2 = Student()
s3 = Student()

print(Student.get_count())
# Out:
# 3

# %%
#15. 3Sum
def threeSum(nums):
        """
        :type nums: List[int]
        :rtype: List[List[int]]
        """
        result=[]
        for i in range(0,len(nums)):
                for j in range(i+1,len(nums)):
                        for k in range(j+1,len(nums)):
                                if(nums[i]+nums[j]+nums[k]==0):
                                        result.append([nums[i],nums[j],nums[k]])
        result = set(result)
        return result
nums = [-1,0,1,2,-1,-4]
threeSum(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      12                                         result.append([nums[i],nums[j],nums[k]])
#      13         result = set(result)
#      14         return result
#      15 nums = [-1,0,1,2,-1,-4]
# ---> 16 threeSum(nums)
#
# Cell In[4], line 13, in threeSum(nums)
#       9                 for j in range(i+1,len(nums)):
#      10                         for k in range(j+1,len(nums)):
#      11                                 if(nums[i]+nums[j]+nums[k]==0):
#      12                                         result.append([nums[i],nums[j],nums[k]])
# ---> 13         result = set(result)
#      14         return result
#
# TypeError: unhashable type: 'list'
