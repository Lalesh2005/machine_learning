# %%
import numpy as np
a= [[1, 2, 3], [4, 5, 6]]
b=list(zip(*a))
b = [list(row) for row in zip(*a)]
print(b)
# Out:
# [[1, 4], [2, 5], [3, 6]]

# %%
A = [[1,2],[2,4]] 
B = [[2,1],[3,4]]

# %%
20%10

# %%
print("Hello")
